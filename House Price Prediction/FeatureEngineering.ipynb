# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2  \
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
X = dataset
y = dataset['SalePrice']

X_test, X_train, y_test, y_train = train_test_split(X, y, train_size = .1, random_state= 0)

# %%
X_train.shape, X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %% [markdown]
# ### Missing Values

# %% [markdown]
# - Find the Categorical Features that are missing

# %%
features_null = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 and dataset[feature].dtypes == 'O']

print("Missing Values Percentage:")
for feature in features_null:
    print(f"{feature}: {np.round(dataset[feature].isnull().mean(), 4) * 100}%")
# Out:
# Missing Values Percentage:
# Alley: 93.77%
# MasVnrType: 59.730000000000004%
# BsmtQual: 2.53%
# BsmtCond: 2.53%
# BsmtExposure: 2.6%
# BsmtFinType1: 2.53%
# BsmtFinType2: 2.6%
# FireplaceQu: 47.260000000000005%
# GarageType: 5.55%
# GarageFinish: 5.55%
# GarageQual: 5.55%
# GarageCond: 5.55%
# PoolQC: 99.52%
# Fence: 80.75%
# MiscFeature: 96.3%

# %% [markdown]
# ### Replace the Missing Values with a new Label

# %%
def replace_cat_features(dataset, features_null):
    data = dataset.copy()

    data[features_null] = data[features_null].fillna('Missing')
    return data

dataset = replace_cat_features(dataset, features_null)

dataset[features_null].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %% [markdown]
# - FInd the Numerical Features that are missing

# %%
num_features_null = [feature for feature in dataset.columns if dataset[feature].isnull().sum() > 1 and dataset[feature].dtypes != 'O']

print("Missing Values Percentage:")
for feature in num_features_null:
    print(f"{feature}: {np.round(dataset[feature].isnull().mean(), 4)* 100}%")
# Out:
# Missing Values Percentage:
# LotFrontage: 17.740000000000002%
# MasVnrArea: 0.5499999999999999%
# GarageYrBlt: 5.55%

# %% [markdown]
# ### Replace the Missing Values
#
# - We will replace the missing values with the median of the features since there exists outliers in dataset

# %%
for feature in num_features_null:
    median_value = dataset[feature].median()

    dataset[feature + 'nan']  = np.where(dataset[feature].isnull(), 1, 0)
    dataset[feature].fillna(median_value, inplace = True)

dataset[num_features_null].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg  \
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD  \
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %% [markdown]
# ### Temporal Variables

# %%
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    dataset[feature] = dataset['YrSold'] - dataset[feature]

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg  \
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD  \
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
dataset[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# ### Numerical Features
#
# - Since the numerical variables are skewed we will perform log normal distribution

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley LotShape
# 0   1          60       RL         65.0     8450   Pave  Missing      Reg  \
# 1   2          20       RL         80.0     9600   Pave  Missing      Reg
# 2   3          60       RL         68.0    11250   Pave  Missing      IR1
# 3   4          70       RL         60.0     9550   Pave  Missing      IR1
# 4   5          60       RL         84.0    14260   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD  \
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %%
num_features = ['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    dataset[feature] = np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape
# 0   1          60       RL     1.428968  2.201872   Pave  Missing      Reg  \
# 1   2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2   3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3   4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4   5          60       RL     1.488584  2.258133   Pave  Missing      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType
# 0         Lvl    AllPub  ...     Missing       0      2   2008       WD  \
# 1         Lvl    AllPub  ...     Missing       0      5   2007       WD
# 2         Lvl    AllPub  ...     Missing       0      9   2008       WD
# 3         Lvl    AllPub  ...     Missing       0      2   2006       WD
# 4         Lvl    AllPub  ...     Missing       0     12   2008       WD
#
#   SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# ...

# %% [markdown]
# ### Handling Rare Categorical Features
#
# - Remove any Categorical Variables that are present in less than 1% of observations

# %%
categorical_features = [feature for feature in dataset.columns if dataset[feature].dtypes == 'O']

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    temp = dataset.groupby(feature)['SalePrice'].count() / len(dataset)
    temp_df = temp[temp > 0.01].index

    dataset[feature] = np.where(dataset[feature].isin(temp_df), dataset[feature], 'Rare_var')

# %%
dataset.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage   LotArea Street    Alley LotShape
# 0     1          60       RL     1.428968  2.201872   Pave  Missing      Reg  \
# 1     2          20       RL     1.477511  2.215885   Pave  Missing      Reg
# 2     3          60       RL     1.439718  2.233034   Pave  Missing      IR1
# 3     4          70       RL     1.409607  2.215315   Pave  Missing      IR1
# 4     5          60       RL     1.488584  2.258133   Pave  Missing      IR1
# ..  ...         ...      ...          ...       ...    ...      ...      ...
# 95   96          60       RL     1.443172  2.217742   Pave  Missing      IR2
# 96   97          20       RL     1.471717  2.223152   Pave  Missing      IR1
# 97   98          20       RL     1.456394  2.229847   Pave  Missing      Reg
# 98   99          30       RL     1.491251  2.226887   Pave  Missing      Reg
# 99  100          20       RL     1.468751  2.212651   Pave  Missing      IR1
#
# ...

# %%
for feature in categorical_features:
    labels_ordered = dataset.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered = {k: i for i, k in enumerate(labels_ordered, 0)}
    dataset[feature] = dataset[feature].map(labels_ordered)

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  LotShape
# 0   1          60         3     1.428968  2.201872       1      2         0  \
# 1   2          20         3     1.477511  2.215885       1      2         0
# 2   3          60         3     1.439718  2.233034       1      2         1
# 3   4          70         3     1.409607  2.215315       1      2         1
# 4   5          60         3     1.488584  2.258133       1      2         1
# 5   6          50         3     1.491251  2.257064       1      2         1
# 6   7          20         3     1.462674  2.221235       1      2         0
# 7   8          60         3     1.443172  2.224389       1      2         1
# 8   9          50         1     1.369104  2.165541       1      2         0
# 9  10         190         3     1.364055  2.187391       1      2         0
#
#    LandContour  Utilities  ...  MiscFeature  MiscVal  MoSold  YrSold
# ...

# %% [markdown]
# ### Feature Scaling

# %%
feature_scale = [feature for feature in dataset.columns if feature not in ['Id', 'SalePrice']]


from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(dataset[feature_scale])
# Out:
# MinMaxScaler()

# %%
scaler.transform(dataset[feature_scale])
# Out:
# array([[0.23529412, 0.75      , 0.49689213, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.57331546, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.51381745, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.50263957, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.51381745, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.54995643, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([dataset[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(dataset[feature_scale]), columns=feature_scale)],
                    axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley
# 0   1  12.247694    0.235294      0.75     0.496892  0.431124     1.0    1.0  \
# 1   2  12.109011    0.000000      0.75     0.573315  0.457169     1.0    1.0
# 2   3  12.317167    0.235294      0.75     0.513817  0.489044     1.0    1.0
# 3   4  11.849398    0.294118      0.75     0.466412  0.456111     1.0    1.0
# 4   5  12.429216    0.235294      0.75     0.590747  0.535696     1.0    1.0
#
#    LotShape  LandContour  ...  Fence  MiscFeature  MiscVal    MoSold  YrSold
# 0  0.000000     0.333333  ...    1.0          1.0      0.0  0.090909    0.50  \
# 1  0.000000     0.333333  ...    1.0          1.0      0.0  0.363636    0.25
# 2  0.333333     0.333333  ...    1.0          1.0      0.0  0.727273    0.50
# 3  0.333333     0.333333  ...    1.0          1.0      0.0  0.090909    0.00
# 4  0.333333     0.333333  ...    1.0          1.0      0.0  1.000000    0.50
#
# ...

# %%
data.to_csv('X_train.csv',index=False)
